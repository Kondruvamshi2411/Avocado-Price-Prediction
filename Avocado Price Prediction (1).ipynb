# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
pip install prophet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet

# %%
avocado_data =pd.read_csv("C:/Users/kondr/Desktop/Datasets/avocado.csv")

# %%
avocado_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avocado_data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avocado_data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
 avocado_data =avocado_data.sort_values('Date')

# %%
avocado_data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11569          51  2015-01-04          1.75      27365.89     9307.34
# 9593           51  2015-01-04          1.49      17723.17     1189.35
# 10009          51  2015-01-04          1.68       2896.72      161.68
# 1819           51  2015-01-04          1.52      54956.80     3013.04
# 9333           51  2015-01-04          1.64       1505.12        1.27
# ...           ...         ...           ...           ...         ...
# 8574            0  2018-03-25          1.36     908202.13   142681.06
# 9018            0  2018-03-25          0.70    9010588.32  3999735.71
# 18141           0  2018-03-25          1.42     163496.70    29253.30
# 17673           0  2018-03-25          1.70     190257.38    29644.09
# 8814            0  2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(avocado_data['Date'],avocado_data['AveragePrice'])

# %%
plt.figure(figsize=(25,12))
sns.countplot(x='region',data=avocado_data)
plt.xticks(rotation=45);

# %%
sns.countplot(x='year',data=avocado_data)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
avocado_prophet_data = avocado_data[['Date','AveragePrice']]

# %%
avocado_prophet_data
# Out:
#              Date  AveragePrice
# 11569  2015-01-04          1.75
# 9593   2015-01-04          1.49
# 10009  2015-01-04          1.68
# 1819   2015-01-04          1.52
# 9333   2015-01-04          1.64
# ...           ...           ...
# 8574   2018-03-25          1.36
# 9018   2018-03-25          0.70
# 18141  2018-03-25          1.42
# 17673  2018-03-25          1.70
# 8814   2018-03-25          1.34
#
# [18249 rows x 2 columns]

# %%
avocado_prophet_df =avocado_prophet_data.rename(columns={'Date':'ds','AveragePrice':'y'})

# %%
avocado_prophet_df
# Out:
#                ds     y
# 11569  2015-01-04  1.75
# 9593   2015-01-04  1.49
# 10009  2015-01-04  1.68
# 1819   2015-01-04  1.52
# 9333   2015-01-04  1.64
# ...           ...   ...
# 8574   2018-03-25  1.36
# 9018   2018-03-25  0.70
# 18141  2018-03-25  1.42
# 17673  2018-03-25  1.70
# 8814   2018-03-25  1.34
#
# [18249 rows x 2 columns]

# %%
m=Prophet()

# %%
m.fit(avocado_prophet_df)
# Out:
# 00:54:22 - cmdstanpy - INFO - Chain [1] start processing
# 00:54:24 - cmdstanpy - INFO - Chain [1] done processing

# %%
#forecast future
future =m.make_future_dataframe(periods=365)
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.498517    0.899747    1.898693     1.498517     1.498517
# 1   2015-01-11  1.493341    0.916676    1.865167     1.493341     1.493341
# 2   2015-01-18  1.488165    0.942615    1.873401     1.488165     1.488165
# 3   2015-01-25  1.482990    0.873614    1.863868     1.482990     1.482990
# 4   2015-02-01  1.477814    0.811411    1.810595     1.477814     1.477814
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.167515    0.589462    1.646360     0.998610     1.343265
# 530 2019-03-22  1.166795    0.539447    1.617115     0.997206     1.343551
# 531 2019-03-23  1.166076    0.552447    1.581950     0.995801     1.343838
# 532 2019-03-24  1.165356    0.553374    1.646518     0.994426     1.344125
# 533 2019-03-25  1.164636    0.532342    1.594894     0.993185     1.344412
#
# ...

# %%
import matplotlib.pyplot as plt
figure=m.plot(forecast,xlabel='Date',ylabel='Price');
# Out:
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
figure =m.plot_components(forecast)
# Out:
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# ...

# %%
avocado_data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 8574            0  2018-03-25          1.36     908202.13   142681.06
# 9018            0  2018-03-25          0.70    9010588.32  3999735.71
# 18141           0  2018-03-25          1.42     163496.70    29253.30
# 17673           0  2018-03-25          1.70     190257.38    29644.09
# 8814            0  2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 8574   463136.28  174975.75   127409.04   103579.41    22467.04      1362.59
# 9018   966589.50   30130.82  4014132.29  3398569.92   546409.74     69152.63
# 18141    5080.04       0.00   129163.36   109052.26    20111.10         0.00
# 17673   70982.10       0.00    89631.19    89424.11      207.08         0.00
# 8814   908653.71     843.45   801373.63   774634.09    23833.93      2905.61
#
#                type  year        region
# 8574   conventional  2018       Chicago
# ...

# %%
avocado_sample_df = avocado_data[avocado_data['region']=='West']

# %%
avocado_df_sample=avocado_sample_df.sort_values('Date')

# %%
avocado_df_sample
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11881          51  2015-01-04          1.40     187548.30    70313.71
# 2755           51  2015-01-04          0.89    5794410.58  2275446.87
# 11880          50  2015-01-11          1.39     223156.55    80139.16
# 2754           50  2015-01-11          0.95    5333097.71  2203111.92
# 2753           49  2015-01-18          0.96    5475363.01  2431736.63
# ...           ...         ...           ...           ...         ...
# 9104            2  2018-03-11          1.00    6906412.50  2442241.76
# 18226           1  2018-03-18          1.73     210067.47    33437.98
# 9103            1  2018-03-18          0.99    7254940.65  2099082.66
# 9102            0  2018-03-25          0.93    7667064.46  2567279.74
# 18225           0  2018-03-25          1.60     271723.08    26996.28
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(avocado_df_sample['Date'],avocado_df_sample['AveragePrice'])

# %%
avocado_sample_df=avocado_df_sample.rename(columns={'Date':'ds','AveragePrice':'y'})

# %%
avocado_sample_df
# Out:
#        Unnamed: 0          ds     y  Total Volume        4046        4225  \
# 11881          51  2015-01-04  1.40     187548.30    70313.71    72942.11
# 2755           51  2015-01-04  0.89    5794410.58  2275446.87  2582300.65
# 11880          50  2015-01-11  1.39     223156.55    80139.16   111395.01
# 2754           50  2015-01-11  0.95    5333097.71  2203111.92  2292761.26
# 2753           49  2015-01-18  0.96    5475363.01  2431736.63  2258069.63
# ...           ...         ...   ...           ...         ...         ...
# 9104            2  2018-03-11  1.00    6906412.50  2442241.76  1695925.97
# 18226           1  2018-03-18  1.73     210067.47    33437.98    47165.54
# 9103            1  2018-03-18  0.99    7254940.65  2099082.66  1707752.84
# 9102            0  2018-03-25  0.93    7667064.46  2567279.74  1912986.38
# 18225           0  2018-03-25  1.60     271723.08    26996.28    77861.39
#
#             4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
m=Prophet()

# %%
m.fit(avocado_sample_df)
# Out:
# 00:54:25 - cmdstanpy - INFO - Chain [1] start processing
# 00:54:26 - cmdstanpy - INFO - Chain [1] done processing

# %%
future =m.make_future_dataframe(periods=365)
forecast=m.predict(future)

# %%
figure=m.plot(forecast,xlabel='Date',ylabel='price');
# Out:
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
figure=m.plot_components(forecast);
# Out:
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\kondr\anaconda3\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# ...
